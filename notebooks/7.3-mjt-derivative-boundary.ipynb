# %%
from __future__ import print_function
import morphs

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sp
from scipy import stats
import pandas as pd
import itertools

from morphs.data.derivative import f_poly, f_map
# Out:
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
dd = morphs.load.derivative_dict()
ddf = morphs.load.derivative_df()
max_order = morphs.data.derivative.find_max_order(dd)

# %%
def gen_boundary_df(block_path, morph_dim, order):
    psychometric_params = morphs.load.psychometric_params()
    popt = dd[block_path][morph_dim][order]
    boundary_df = pd.DataFrame(
        [
            (
                boundary_subj,
                boundary_dim,
                psychometric_params[boundary_subj][boundary_dim][3],
                psychometric_params[boundary_subj][boundary_dim][2],
            )
            for boundary_subj in psychometric_params
            for boundary_dim in psychometric_params[boundary_subj]
        ],
        columns=[
            "boundary_subj",
            "boundary_dim",
            "boundary_loc",
            "boundary_sensitivity",
        ],
    )
    boundary_df["fval"] = (
        f_poly(boundary_df["boundary_loc"].values, popt)
        / sp.integrate.quad(f_poly, 1, 128, args=(popt,))[0]
    )
    boundary_df["morph_dim"] = morph_dim
    boundary_df["block_path"] = block_path
    boundary_df["order"] = order
    return boundary_df

# %%
deriv_val_df = pd.concat(
    [
        gen_boundary_df(block_path, morph_dim, order)
        for order in range(max_order + 1)
        for block_path in dd
        for morph_dim in dd[block_path]
    ],
    ignore_index=True,
)

deriv_val_df["matched"] = deriv_val_df["boundary_dim"] == deriv_val_df["morph_dim"]
# Out:
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
# ...
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/ipykernel_launcher.py:19: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.

# %%
cor_plot_data = (
    deriv_val_df[deriv_val_df["matched"] & (deriv_val_df["order"] == 4)]
    .groupby(["morph_dim", "boundary_subj"])
    .agg(np.mean)
)
g = sns.jointplot(
    data=cor_plot_data,
    x="fval",
    y="boundary_sensitivity",
    kind="reg",
    xlim=(0, 0.05),
    ylim=(0, 1.2),
    joint_kws={"marker": "."},
)
g = g.annotate(stats.pearsonr)
g = g.set_axis_labels("$\partial N / \partial s$", "Boundary Sensitivity (B)")
# Out:
# /usr/local/anaconda/envs/morphs36/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
g = sns.jointplot(
    data=cor_plot_data,
    x="fval",
    y="boundary_sensitivity",
    kind="reg",
    xlim=(0, 0.05),
    ylim=(0, 1.2),
    joint_kws={"marker": "."},
)
# g = g.annotate(stats.pearsonr)
g = g.set_axis_labels("$\partial N / \partial s$", "Boundary Sensitivity (B)")
morphs.plot.savefig(g, "thielkness-vs-B")

# %%
def ks_mapper(group, return_p=True):
    matched_groups = group.groupby("matched")
    d, p = sp.stats.mstats.ks_twosamp(
        matched_groups.get_group(False)["fval"].values,
        matched_groups.get_group(True)["fval"].values,
        alternative="greater",
    )
    return p if return_p else d

# %%
deriv_val_df.groupby("order").apply(ks_mapper)
# Out:
# order
# 0      9.139957e-01
# 1      7.133268e-30
# 2      9.233846e-57
# 3     3.786218e-105
# 4     1.472594e-121
# 5     2.096174e-136
# 6     1.472099e-138
# 7     3.258502e-122
# 8     1.177891e-101
# 9      0.000000e+00
# 10     0.000000e+00
# 11     0.000000e+00
# 12     0.000000e+00
# 13     0.000000e+00
# dtype: float64

# %%
for order, order_group in deriv_val_df.groupby("order"):
    matched_groups = order_group.groupby("matched")
    fig = plt.figure(figsize=(6, 3))
    ax = plt.gca()
    for matched, matched_group in matched_groups:
        morphs.plot.cumulative_distribution(
            matched_group["fval"].values,
            scaled=True,
            label="same dimension" if matched else "different dimension",
        )
    ax.set_ylim(0, 1)
    ax.set_xlim(0, 0.1)
    ax.set_ylabel("Cumulative Distribution")
    ax.set_xlabel("$\partial N / \partial s$")
    ax.legend(loc="lower right")
    ax.set_title("order %d" % (order))

# %%
order = 4
order_group = deriv_val_df.groupby("order").get_group(order)
matched_groups = order_group.groupby("matched")
fig = plt.figure(figsize=(6, 3))
ax = plt.gca()
for matched, matched_group in matched_groups:
    morphs.plot.cumulative_distribution(
        matched_group["fval"].values,
        scaled=True,
        label="same dimension" if matched else "different dimension",
    )
ax.set_ylim(0, 1)
ax.set_xlim(0, 0.1)
ax.set_ylabel("Cumulative Distribution")
ax.set_xlabel("$\partial N / \partial s$")
morphs.plot.savefig(fig, "boundary-thielkness")

# %%
deriv_val_df["neural_subj"] = deriv_val_df["block_path"].map(morphs.data.parse.bird_id)
morphs.data.parse.ephys_class(
    deriv_val_df, behavior_subj_label="boundary_subj", neural_subj_label="neural_subj"
)

# %%
for order, order_group in deriv_val_df.groupby("order"):
    fig = plt.figure()
    ax = plt.gca()
    for _class, class_group in order_group.groupby("class"):
        for matched, matched_group in class_group.groupby("matched"):
            morphs.plot.cumulative_distribution(
                matched_group["fval"].values,
                scaled=True,
                label=_class
                + (" same dimension" if matched else " different dimension"),
            )
    ax.set_ylim(0, 1)
    ax.set_xlim(0, 0.1)
    ax.set_ylabel("Cumulative Distribution")
    ax.set_xlabel("$\partial N / \partial s$")
    ax.legend(loc="lower right")
    ax.set_title("order %d" % (order))

# %%
block_subj_df = (
    deriv_val_df.groupby(["order", "boundary_subj", "block_path"])
    .apply(ks_mapper, return_p=False)
    .rename("d")
    .reset_index()
)

# %%
block_subj_df["neural_subj"] = block_subj_df["block_path"].map(
    morphs.data.parse.bird_id
)
morphs.data.parse.ephys_class(
    block_subj_df, behavior_subj_label="boundary_subj", neural_subj_label="neural_subj"
)

# %%
block_subj_df.groupby(["order", "class"])["d"].mean()
# Out:
# order  class
# 0      naive      0.037228
#        self       0.052632
#        trained    0.037267
# 1      naive      0.191933
#        self       0.178776
#        trained    0.225400
# 2      naive      0.207558
#        self       0.180206
#        trained    0.234227
# 3      naive      0.272605
#        self       0.217105
#        trained    0.257927
# 4      naive      0.285326
#        self       0.251144
#        trained    0.260093
# 5      naive      0.311515
#        self       0.253146
#        trained    0.264077
# 6      naive      0.316780
#        self       0.228261
#        trained    0.256089
# 7      naive      0.307439
#        self       0.232838
#        trained    0.257784
# 8      naive      0.304603
#        self       0.278318
#        trained    0.287001
# 9      naive      0.385649
#        self       0.437071
#        trained    0.453866
# 10     naive      0.543224
#        self       0.616848
#        trained    0.615234
# 11     naive      0.550713
#        self       0.561499
#        trained    0.567853
# 12     naive      0.500798
#        self       0.532323
#        trained    0.534938
# 13     naive      0.463927
#        self       0.515875
#        trained    0.520963
# Name: d, dtype: float64

# %%
print("order", "vs", "class0", "class1", "d", "p")
for order, order_group in deriv_val_df.groupby("order"):
    for matched, matched_group in order_group.groupby("matched"):
        if matched:
            class_gb = order_group.groupby("class")
            for class0, class1 in itertools.combinations(class_gb.groups.keys(), 2):
                d, p = sp.stats.mstats.ks_twosamp(
                    class_gb.get_group(class0)["fval"].values,
                    class_gb.get_group(class1)["fval"].values,
                    alternative="two-sided",
                )
                print(order, "vs", class0, class1, d, p)
# Out:
# order vs class0 class1 d p
# 0 vs naive self 0.019407894736848626 0.014702155181923516
# 0 vs naive trained 0.019407894736864627 1.501711145378141e-09
# 0 vs self trained 3.942228488096333e-13 1.0
# 1 vs naive self 0.10726682428731187 1.3293680715553559e-65
# 1 vs naive trained 0.0927771087876847 6.151176232910745e-209
# 1 vs self trained 0.042704417293251876 1.544058873444034e-10
# 2 vs naive self 0.07232044956136294 4.7204813073846026e-30
# 2 vs naive trained 0.07907378309045723 6.842818047017057e-152
# 2 vs self trained 0.010494987468664578 0.48287819676517385
# 3 vs naive self 0.07345206277413013 5.489988451659702e-31
# 3 vs naive trained 0.06436623786028299 8.706501583628449e-101
# 3 vs self trained 0.013764880952399514 0.17786405866857719
# 4 vs naive self 0.08491810581141174 2.8406467573780085e-41
# 4 vs naive trained 0.06433833607456986 1.0637386078517582e-100
# 4 vs self trained 0.02349624060150981 0.0017367755787672983
# 5 vs naive self 0.0800738418311532 9.569697512857297e-37
# 5 vs naive trained 0.05984969748590503 3.3904669884206723e-87
# 5 vs self trained 0.02514097744361742 0.000625407838854013
# 6 vs naive self 0.0701968544408014 2.4454546223648318e-28
# 6 vs naive trained 0.059213218593363925 2.3227090082549216e-85
# 6 vs self trained 0.01562500000002039 0.0885553806304425
# 7 vs naive self 0.06838336074562044 6.485515240171307e-27
# 7 vs naive trained 0.06168338326284837 1.3546000221216356e-92
# 7 vs self trained 0.050438596491248135 1.5634303385337632e-14
# 8 vs naive self 0.19736842105264796 4.38678069550408e-221
# 8 vs naive trained 0.19736842105259542 0.0
# 8 vs self trained 0.1973684210526422 1.9800185524536826e-216
# 9 vs naive self 0.41008771929817167 0.0
# 9 vs naive trained 0.41008771929815013 0.0
# 9 vs self trained 0.41008771929826165 0.0
# 10 vs naive self 0.5855263157892638 0.0
# 10 vs naive trained 0.5855263157892716 0.0
# 10 vs self trained 0.5855263157894879 0.0
# 11 vs naive self 0.5350877192980679 0.0
# 11 vs naive trained 0.5350877192980724 0.0
# 11 vs self trained 0.5350877192982607 0.0
# 12 vs naive self 0.5043859649121266 0.0
# 12 vs naive trained 0.5043859649121344 0.0
# 12 vs self trained 0.5043859649122938 0.0
# 13 vs naive self 0.4912280701753172 0.0
# 13 vs naive trained 0.4912280701753253 0.0
# 13 vs self trained 0.49122807017545284 0.0

# %%
for order, order_group in block_subj_df.groupby("order"):
    fig = plt.figure()
    ax = plt.gca()
    for _class, class_group in order_group.groupby("class"):
        morphs.plot.cumulative_distribution(
            class_group["d"].values, scaled=True, label=_class
        )
    ax.set_ylim(0, 1)
    ax.set_ylabel("Cumulative Distribution")
    ax.set_xlabel("d")
    ax.legend(loc="lower right")
    ax.set_title("order %d" % (order))

# %% [markdown]
# There may be something worth arguing about how naive birds might have better peaks, but there are considerable caveats to this kind of interpretation so I won't bother for now.
