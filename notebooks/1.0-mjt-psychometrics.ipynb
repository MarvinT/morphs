# %%
import morphs
import pandas as pd

# %%
behavior_df = morphs.data.load.behavior_df()
morphs.data.parse.stim_id(behavior_df)
behavior_df = morphs.data.parse.behav_data_inverted(behavior_df)

# %%
behavior_df.groupby('subj').agg('count')['response']
# Out:
# subj
# B1082    1280159
# B1088     545599
# B1101     321631
# B1105    1486927
# B1107     111549
# B1218     449423
# B1222    1248989
# B979       68701
# Name: response, dtype: int64

# %%
def reduce_behave_data(df):
    '''Trims df and changes dtypes to reduce pkl size'''
    df = df[['type_', 'class_', 'response', 'correct', 'rt', 'reward', 'stim_id', 'subj']]
    for col in ['correct', 'reward']:
        df[col] = df[col].astype(bool)
    for col in ['type_', 'class_', 'response', 'subj']:
        df[col] = df[col].astype('category')
    return df


def gen_behavior_df():
    '''Loads raw data and generates pkl containing all important behavior data'''
    import behav
    from behav import loading
    behav_data = loading.load_data_pandas(morphs.subj.BEHAVE_SUBJS,
                                          morphs.paths.behave_data_folder())
    behavior_df = pd.concat([morphs.data.parse.behav_data_stim_id(behav_data[subj], subj) for
                             subj in morphs.subj.BEHAVE_SUBJS])
    behavior_df = reduce_behave_data(behavior_df)
    return behavior_df

# %%
type_behavior_df = gen_behavior_df()
# Out:
# /usr/local/home/mthielk/GitHub/morphs/morphs/data/parse.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['stim_id'] = df['stimulus'].str.split('/').str[-1].str[:-4]
# /usr/local/anaconda/envs/morphs/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/anaconda/envs/morphs/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
morphs.data.parse.stim_id(type_behavior_df)
type_behavior_df = morphs.data.parse.behav_data_inverted(type_behavior_df)

# %%
old_psychometric_params = morphs.data.load.psychometric_params()

# %%
new_psychometric_params = morphs.data.psychometric.calculate_psychometric_params(type_behavior_df[type_behavior_df['type_'] == 'normal'])

# %%
for bird in new_psychometric_params:
    for dim in new_psychometric_params[bird]:
        print(bird, dim, new_psychometric_params[bird][dim] - old_psychometric_params[bird][dim])
# Out:
# ('B1218', 'be', array([0., 0., 0., 0.]))
# ('B1218', 'bf', array([0., 0., 0., 0.]))
# ('B1218', 'bg', array([0., 0., 0., 0.]))
# ('B1218', 'ae', array([0., 0., 0., 0.]))
# ('B1218', 'dh', array([0., 0., 0., 0.]))
# ('B1218', 'ag', array([0., 0., 0., 0.]))
# ('B1218', 'af', array([0., 0., 0., 0.]))
# ('B1218', 'df', array([0., 0., 0., 0.]))
# ('B1218', 'ah', array([0., 0., 0., 0.]))
# ('B1218', 'de', array([0., 0., 0., 0.]))
# ('B1218', 'bh', array([0., 0., 0., 0.]))
# ('B1218', 'cf', array([0., 0., 0., 0.]))
# ('B1218', 'ce', array([0., 0., 0., 0.]))
# ('B1218', 'ch', array([0., 0., 0., 0.]))
# ('B1218', 'cg', array([0., 0., 0., 0.]))
# ('B1218', 'dg', array([0., 0., 0., 0.]))
# ('B1082', 'be', array([0., 0., 0., 0.]))
# ('B1082', 'bf', array([0., 0., 0., 0.]))
# ('B1082', 'bg', array([0., 0., 0., 0.]))
# ('B1082', 'ae', array([0., 0., 0., 0.]))
# ('B1082', 'dh', array([0., 0., 0., 0.]))
# ('B1082', 'ag', array([0., 0., 0., 0.]))
# ('B1082', 'af', array([0., 0., 0., 0.]))
# ...

# %%
new_psychometric_params[bird][dim]
# Out:
# array([ 0.08001777,  0.9312611 ,  0.25421866, 67.68288999])

# %%
type_behavior_df[type_behavior_df['type_'] == 'normal']
# Out:
#                              type_ class_ response  correct        rt  reward  \
# time
# 2015-06-25 15:42:25.669590  normal      R        L    False  0.364958   False
# 2015-06-25 15:50:44.913341  normal      R        L    False  0.212025   False
# 2015-06-25 15:55:13.504033  normal      L        L     True  0.484456   False
# 2015-06-25 15:55:39.668859  normal      R        L    False  0.470960   False
# 2015-06-25 15:58:18.444810  normal      L        L     True  0.532172   False
# 2015-06-25 15:58:26.252810  normal      L        R    False  1.989614   False
# 2015-06-25 16:00:05.558497  normal      L        R    False  0.589235   False
# 2015-06-25 16:03:01.162564  normal      R        R     True  0.896169   False
# 2015-06-25 16:03:08.968311  normal      R        L    False  0.501740   False
# 2015-06-25 16:04:23.293765  normal      R        R     True  1.822207   False
# 2015-06-25 16:04:32.120772  normal      L        R    False  0.653790   False
# ...
